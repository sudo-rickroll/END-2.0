# %%
from google.colab import drive
drive.mount('GDrive')
# Out:
# Mounted at GDrive

# %%
# %cd '/content/GDrive/MyDrive/END2_S3'
# Out:
# /content/GDrive/MyDrive/END2_S3

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# %run main.py --mode 'Train' --checkpoint_save './checkpoint/mnist_sum.pth'
# Out:
# Training the model...
#
# Epoch 1 :
#
# Training stats :
# Accuracy MNIST=  91.53
# Accuracy Total=  18.59
# Loss MNIST=  181.12509246
# Loss Total=  1584.50594914
#
# Validation stats :
# Accuracy MNIST=  96.95
# Accuracy Total=  29.05
# Loss MNIST=  10.86792716
# Loss Total=  202.83029521
# ------------------------
# Saving model checkpoint in './checkpoint/mnist_sum.pth'

# %%
# %run main.py --mode 'Validate' --checkpoint_load './checkpoint/mnist_sum.pth'
# Out:
# Loading model checkpoint from './checkpoint/mnist_sum.pth'
#
# Validating the model...
# Validation stats :
# Accuracy MNIST=  96.95
# Accuracy Total=  29.63
# Loss MNIST=  10.86792716
# Loss Total=  202.46213794
# ------------------------
