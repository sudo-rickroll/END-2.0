# %% [markdown]
# # Mounting Google Drive to import the project packages

# %%
from google.colab import drive
drive.mount('GDrive')
# Out:
# Mounted at GDrive

# %% [markdown]
# # Changing the directory to the drive folder where the packages are located

# %%
# %cd '/content/GDrive/MyDrive/END2_S3'
# Out:
# /content/GDrive/MyDrive/END2_S3

# %% [markdown]
# # Configuration changes to plot the matplotlib graphs inside the notebook and to ignore warnings

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #Running the model on the Train Dataset and displaying the corresponding statistics

# %%
# %run main.py --mode 'Train' --checkpoint_save './checkpoint/mnist_sum.pth'
# Out:
# Training the model...
#
# Epoch 1 :
#
# Training stats :
# Accuracy MNIST=  91.92
# Accuracy Total=  17.13
# Loss MNIST=  180.41389167
# Loss Total=  1603.75331843
#
# Validation stats :
# Accuracy MNIST=  97.70
# Accuracy Total=  29.02
# Loss MNIST=  7.93100494
# Loss Total=  202.87954724
# ------------------------
#
# Epoch 2 :
#
# Training stats :
# Accuracy MNIST=  98.52
# Accuracy Total=  36.72
# Loss MNIST=  32.63154367
# Loss Total=  1041.64075673
#
# Validation stats :
# Accuracy MNIST=  98.46
# Accuracy Total=  42.33
# Loss MNIST=  5.35978113
# Loss Total=  155.74314892
# ------------------------
#
# Epoch 3 :
#
# Training stats :
# Accuracy MNIST=  98.85
# Accuracy Total=  47.71
# Loss MNIST=  23.73996187
# Loss Total=  848.74871635
#
# Validation stats :
# Accuracy MNIST=  98.80
# Accuracy Total=  52.10
# Loss MNIST=  4.17304231
# Loss Total=  133.33225846
# ------------------------
#
# Epoch 4 :
#
# Training stats :
# Accuracy MNIST=  99.07
# Accuracy Total=  54.51
# Loss MNIST=  19.37560610
# Loss Total=  748.33224708
#
# Validation stats :
# Accuracy MNIST=  99.00
# Accuracy Total=  57.61
# Loss MNIST=  3.47429296
# Loss Total=  120.58941656
# ------------------------
#
# Epoch 5 :
#
# Training stats :
# Accuracy MNIST=  99.21
# Accuracy Total=  58.66
# Loss MNIST=  16.54201279
# Loss Total=  683.44435400
#
# Validation stats :
# Accuracy MNIST=  99.02
# Accuracy Total=  61.17
# Loss MNIST=  3.22930349
# Loss Total=  112.71460593
# ------------------------
#
# Epoch 6 :
#
# Training stats :
# Accuracy MNIST=  99.30
# Accuracy Total=  61.69
# Loss MNIST=  14.44736535
# Loss Total=  637.68328506
#
# Validation stats :
# Accuracy MNIST=  99.03
# Accuracy Total=  63.13
# Loss MNIST=  3.05505533
# Loss Total=  107.17005634
# ------------------------
#
# Epoch 7 :
#
# Training stats :
# Accuracy MNIST=  99.41
# Accuracy Total=  64.08
# Loss MNIST=  12.66355599
# Loss Total=  601.78228438
#
# Validation stats :
# Accuracy MNIST=  99.11
# Accuracy Total=  64.42
# Loss MNIST=  2.78692129
# Loss Total=  102.23562133
# ------------------------
#
# Epoch 8 :
#
# Training stats :
# Accuracy MNIST=  99.50
# Accuracy Total=  65.93
# Loss MNIST=  11.15292908
# Loss Total=  571.42837030
#
# Validation stats :
# Accuracy MNIST=  99.11
# Accuracy Total=  65.58
# Loss MNIST=  2.74148766
# Loss Total=  99.30725324
# ------------------------
#
# Epoch 9 :
#
# Training stats :
# Accuracy MNIST=  99.54
# Accuracy Total=  67.47
# Loss MNIST=  10.05424180
# Loss Total=  546.46787971
#
# Validation stats :
# Accuracy MNIST=  99.18
# Accuracy Total=  66.29
# Loss MNIST=  2.72059764
# Loss Total=  97.05650753
# ------------------------
#
# Epoch 10 :
#
# Training stats :
# Accuracy MNIST=  99.59
# Accuracy Total=  68.75
# Loss MNIST=  9.22450854
# Loss Total=  525.25267702
#
# Validation stats :
# Accuracy MNIST=  99.12
# Accuracy Total=  66.38
# Loss MNIST=  2.76683422
# Loss Total=  95.25993210
# ------------------------
#
# Epoch 11 :
#
# Training stats :
# Accuracy MNIST=  99.63
# Accuracy Total=  69.64
# Loss MNIST=  8.44889980
# Loss Total=  505.51280707
#
# Validation stats :
# Accuracy MNIST=  99.12
# Accuracy Total=  67.09
# Loss MNIST=  2.65180709
# Loss Total=  93.00316888
# ------------------------
#
# Epoch 12 :
#
# Training stats :
# Accuracy MNIST=  99.66
# Accuracy Total=  70.72
# Loss MNIST=  7.83050959
# Loss Total=  487.70999968
#
# Validation stats :
# Accuracy MNIST=  99.22
# Accuracy Total=  67.54
# Loss MNIST=  2.54963634
# Loss Total=  91.18954813
# ------------------------
#
# Epoch 13 :
#
# Training stats :
# Accuracy MNIST=  99.67
# Accuracy Total=  71.57
# Loss MNIST=  7.52693509
# Loss Total=  472.26198709
#
# Validation stats :
# Accuracy MNIST=  99.18
# Accuracy Total=  68.67
# Loss MNIST=  2.52934799
# Loss Total=  89.45977575
# ------------------------
#
# Epoch 14 :
#
# Training stats :
# Accuracy MNIST=  99.71
# Accuracy Total=  72.67
# Loss MNIST=  6.80474305
# Loss Total=  455.79703945
#
# Validation stats :
# Accuracy MNIST=  99.15
# Accuracy Total=  68.85
# Loss MNIST=  2.61994632
# Loss Total=  89.22845608
# ------------------------
#
# Epoch 15 :
#
# Training stats :
# Accuracy MNIST=  99.71
# Accuracy Total=  73.41
# Loss MNIST=  6.43143809
# Loss Total=  442.42722631
#
# Validation stats :
# Accuracy MNIST=  99.18
# Accuracy Total=  69.25
# Loss MNIST=  2.60742918
# Loss Total=  87.80346096
# ------------------------
#
# Epoch 16 :
#
# Training stats :
# Accuracy MNIST=  99.74
# Accuracy Total=  74.28
# Loss MNIST=  5.95414635
# Loss Total=  428.62225184
#
# Validation stats :
# Accuracy MNIST=  99.21
# Accuracy Total=  69.98
# Loss MNIST=  2.67717711
# Loss Total=  87.92556795
# ------------------------
#
# Epoch 17 :
#
# Training stats :
# Accuracy MNIST=  99.74
# Accuracy Total=  75.10
# Loss MNIST=  5.60051816
# Loss Total=  417.04000825
#
# Validation stats :
# Accuracy MNIST=  99.19
# Accuracy Total=  69.94
# Loss MNIST=  2.67801409
# Loss Total=  86.77110526
# ------------------------
#
# Epoch 18 :
#
# Training stats :
# Accuracy MNIST=  99.78
# Accuracy Total=  75.63
# Loss MNIST=  5.17554431
# Loss Total=  406.20998374
#
# Validation stats :
# Accuracy MNIST=  99.15
# Accuracy Total=  70.39
# Loss MNIST=  2.76277939
# Loss Total=  87.98391274
# ------------------------
#
# Epoch 19 :
#
# Training stats :
# Accuracy MNIST=  99.81
# Accuracy Total=  76.34
# Loss MNIST=  4.82531535
# Loss Total=  392.99765384
#
# Validation stats :
# Accuracy MNIST=  99.10
# Accuracy Total=  70.57
# Loss MNIST=  2.84068485
# Loss Total=  87.67404699
# ------------------------
#
# Epoch 20 :
#
# Training stats :
# Accuracy MNIST=  99.84
# Accuracy Total=  77.07
# Loss MNIST=  4.56199211
# Loss Total=  381.56976715
#
# Validation stats :
# Accuracy MNIST=  99.10
# Accuracy Total=  70.76
# Loss MNIST=  2.87845873
# Loss Total=  88.98761562
# ------------------------
#
# Epoch 21 :
#
# Training stats :
# Accuracy MNIST=  99.82
# Accuracy Total=  77.43
# Loss MNIST=  4.30066016
# Loss Total=  373.73779744
#
# Validation stats :
# Accuracy MNIST=  99.11
# Accuracy Total=  71.17
# Loss MNIST=  2.89522961
# Loss Total=  88.21778014
# ------------------------
#
# Epoch 22 :
#
# Training stats :
# Accuracy MNIST=  99.83
# Accuracy Total=  77.86
# Loss MNIST=  4.17455132
# Loss Total=  365.42280066
#
# Validation stats :
# Accuracy MNIST=  99.11
# Accuracy Total=  71.53
# Loss MNIST=  2.85855335
# Loss Total=  87.68177658
# ------------------------
#
# Epoch 23 :
#
# Training stats :
# Accuracy MNIST=  99.86
# Accuracy Total=  78.91
# Loss MNIST=  3.79657481
# Loss Total=  351.76909053
#
# Validation stats :
# Accuracy MNIST=  99.09
# Accuracy Total=  72.01
# Loss MNIST=  2.93275641
# Loss Total=  87.99145645
# ------------------------
#
# Epoch 24 :
#
# Training stats :
# Accuracy MNIST=  99.85
# Accuracy Total=  79.19
# Loss MNIST=  3.64253620
# Loss Total=  345.85063744
#
# Validation stats :
# Accuracy MNIST=  99.12
# Accuracy Total=  71.54
# Loss MNIST=  3.12245242
# Loss Total=  90.67466620
# ------------------------
#
# Epoch 25 :
#
# Training stats :
# Accuracy MNIST=  99.87
# Accuracy Total=  79.68
# Loss MNIST=  3.53222048
# Loss Total=  337.42002887
#
# Validation stats :
# Accuracy MNIST=  99.02
# Accuracy Total=  71.80
# Loss MNIST=  3.08255807
# Loss Total=  89.91670829
# ------------------------
# Saving model checkpoint in './checkpoint/mnist_sum.pth'
# Model saved successfully

# %% [markdown]
# # Running the model on the Test Dataset and displaying the corresponding statistics

# %%
# %run main.py --mode 'Validate' --checkpoint_load './checkpoint/mnist_sum.pth'
# Out:
# Loading model checkpoint from './checkpoint/mnist_sum.pth'
# Model loaded successfully
#
# Validating the model...
#
# Sample of validation :
# Validation stats :
# Accuracy MNIST=  99.02
# Accuracy Total=  73.23
# Loss MNIST=  3.08255807
# Loss Total=  89.13328835
# ------------------------
